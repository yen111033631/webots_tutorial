# %%
def calculate_distance(a_position, b_position):
    assert len(a_position) == len(b_position), "Error: length not the same, cant calculate"
    
    tem = 0
    for i in range(len(a_position)):
        tem += (a_position[i] - b_position[i]) ** 2
    
    distance = tem ** 0.5

    return distance

# %%
a = [0, 1]
b = [1, 0, 1]
calculate_distance(a, b)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 a = [0, 1]
#       2 b = [1, 0, 1]
# ----> 3 calculate_distance(a, b)
#
# Cell In[16], line 2, in calculate_distance(a_position, b_position)
#       1 def calculate_distance(a_position, b_position):
# ----> 2     assert len(a_position) == len(b_position), "Error: length not the same, cant calculate"
#       4     tem = 0
#       5     for i in range(len(a_position)):
#
# AssertionError: Error: length not the same, cant calculate

# %%
# Out:
# 1

# %%
import random

# Set the random seed for reproducibility
random_seed = 42
random.seed(random_seed)

# Generate a random integer between 0 and 10
random_number = random.randint(0, 1)

# Print the randomly chosen number
print("Randomly chosen number:", random_number)
# Out:
# Randomly chosen number: 0

# %%
random.randint(0, 1)
# Out:
# 0

# %%
class object12:
    def __init__(self, DEF_name):
        self.name = DEF_name
        self.position = 0
        self.grade = {}

    def read_position(self):
        

    def __str__(self):
        return (f'object name: {self.name}, object position: {self.position}')
    
    
    # def __getattr__(self, name):
    #     print(type(name))
    #     print(f"Looking for {name}?")
    #     return None
    # def __getattribute__(self, name):
    #     if name == "position":
    #         self.position = random.randint(0, 5)
    
    def __getattribute__(self, name):
        print(name)
        return self.__getattribute__(self, name)

        # return object.__getattribute__(self, name)
    
    # def __setattr__(self, name, value):
    #     print(f"改變{name}的值為{value}")
    #     self.__dict__[name] = value

# %%
ball = object12("ball")
print(ball)
# Out:
# name
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# __getattribute__
# ...

# %%
print(ball.name)
# Out:
# None

# %%
ball.position
